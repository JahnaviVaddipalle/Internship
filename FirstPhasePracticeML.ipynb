# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# Loading the raw file, so that no error occurs

# %%
df = pd.read_csv("C:/Users/vaddi/Downloads/documents/winequality-red.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.sample()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1540            6.2              0.52         0.08             4.4      0.071
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1540                 11.0                  32.0  0.99646  3.56       0.63
#
#       alcohol  quality
# 1540     11.6        6

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# The df.shape shows the no. of rows and columns the dataframe contains. This df contains 1599 rows and 12 columns

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# The above data shows that there are no null values present in the given data

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# The above, shows the data types of the columns present in df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# From the above details we can observe the following:
#     1. The data shows that the mean value is higher than the median which indicates there is skewness in the data
#     2. There is huge difference between 75% and max value for residual sugar, free sulfur dioxide and total sulfur dioxide which means outliers are present.

# %%
#Visualize the quality of wine 
ax = sns.countplot(x='quality',data=df)
print(df['quality'].value_counts())
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# We can observe that from the above graph that  there are only 18 highest quality wine with 8 rating and the lowest 10 with 3 rating. The major quantity of wine is rated with 5, 6 and 7

# %% [markdown]
# To check the correlation

# %%
dfcor = df.corr()
dfcor
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(dfcor,annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above heatmap, we can observe that the quality is highly correlated with the alcohal
# density is highly positively correlated with residual sugar
# And the darker colors in the headmap shows the negative correlation,
# as it is observed here, quality is negatively correlated with the volatile acidity
# alcohol is negatively correlated with the density

# %%
 df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# Checking for the outliers

# %%
df['fixed acidity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['volatile acidity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['citric acid'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['residual sugar'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['chlorides'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['free sulfur dioxide'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['total sulfur dioxide'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['density'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['pH'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['sulphates'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['alcohol'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above box plots created for each column or attribute it is evedient that the outliers are present for all the attributes.

# %% [markdown]
# Removing the outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.528360          0.961877     1.391472        0.453218   0.243707
# 1          0.298547          1.967442     1.391472        0.043416   0.223875
# 2          0.298547          1.297065     1.186070        0.169427   0.096353
# 3          1.654856          1.384443     1.484154        0.453218   0.264960
# 4          0.528360          0.961877     1.391472        0.453218   0.243707
# ...             ...               ...          ...             ...        ...
# 1594       1.217796          0.403229     0.980669        0.382271   0.053845
# 1595       1.390155          0.123905     0.877968        0.240375   0.541259
# 1596       1.160343          0.099554     0.723916        0.169427   0.243707
# 1597       1.390155          0.654620     0.775267        0.382271   0.264960
# 1598       1.332702          1.216849     1.021999        0.752894   0.434990
#
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#          45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#         106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#         151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#         244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#         354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#         459,  467,  480,  480,  494,  515,  517,  544,  554,  554,  555,
#         555,  557,  557,  568,  584,  588,  591,  595,  608,  614,  636,
#         639,  649,  649,  651,  652,  652,  652,  672,  672,  684,  690,
#         690,  692,  692,  695,  723,  724,  730,  754,  776,  777,  795,
#         821,  832,  836,  837,  889,  899,  911,  917,  923,  925,  926,
#         982, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1079, 1081,
#        1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186, 1231, 1235, 1244,
# ...

# %% [markdown]
# The above data shows the rows and columns that contains the high z score values, like 13th row 9th column and 14th row 5th column and so on
#
# Let's verify it

# %%
z.iloc[13][9]
# Out:
# 5.32210116796055

# %%
z.iloc[14][5]
# Out:
# 3.454668962073944

# %%
z.iloc[1589][3]
# Out:
# 3.732701384742145

# %% [markdown]
# Will remove the data that contains outliers and create new data set

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# Importing the required libraried to divide the data into 2 parts, 70% for the training, i.e., the machine learns from the 70% of the data and then train from the rest 30% so that the classification report can be created

# %%
x=df_new.iloc[:,0:-1] #the dataset is divided into the x and y, x contains all the attributes that effect the quality which is y

# %%
y=df_new.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=47) 
#Splitting the data for the test and train, the test size should be 30 and random_state can be chaged and the result can be seen in the accuracy of the data

# %%
x_train.shape
# Out:
# (1015, 11)

# %% [markdown]
# Here the x_train data contains 1015 rows and 11 columns

# %%
x_test.shape
# Out:
# (436, 11)

# %% [markdown]
# Here the x_test data contains 436 rows and 11 columns

# %%
y_train.shape
# Out:
# (1015,)

# %% [markdown]
# The y train data contains 1015 rows and 1 column

# %%
y_test.shape
# Out:
# (436,)

# %% [markdown]
# The y test data contains 436 rows and 1 column

# %%
mnb=MultinomialNB()
mnb.fit(x_train,y_train) #Naive Bayes method is used to predict the data
# Out:
# MultinomialNB()

# %%
pred=mnb.predict(x_test)
pred
# Out:
# array([5, 7, 6, 5, 5, 6, 5, 6, 6, 6, 5, 5, 5, 7, 6, 5, 6, 5, 5, 5, 5, 5,
#        6, 5, 7, 7, 5, 6, 5, 6, 6, 7, 5, 5, 5, 6, 6, 6, 5, 6, 5, 5, 6, 6,
#        7, 5, 7, 6, 6, 6, 6, 5, 5, 6, 5, 7, 5, 5, 6, 7, 7, 5, 7, 5, 6, 5,
#        7, 5, 7, 5, 5, 7, 6, 7, 5, 5, 6, 6, 6, 7, 5, 6, 5, 6, 7, 6, 7, 7,
#        5, 5, 6, 6, 6, 6, 7, 7, 7, 6, 6, 7, 6, 7, 6, 6, 7, 6, 5, 5, 6, 6,
#        7, 7, 7, 5, 6, 6, 6, 7, 6, 7, 6, 6, 5, 5, 6, 6, 6, 6, 5, 7, 5, 7,
#        5, 7, 6, 5, 5, 5, 6, 6, 5, 6, 6, 5, 5, 5, 7, 6, 7, 6, 7, 5, 5, 6,
#        5, 7, 7, 5, 6, 6, 7, 5, 5, 5, 6, 7, 5, 5, 6, 7, 6, 6, 5, 5, 5, 6,
#        5, 6, 6, 5, 5, 7, 7, 6, 7, 7, 7, 6, 6, 5, 5, 6, 5, 6, 6, 6, 6, 6,
#        5, 6, 5, 6, 6, 5, 7, 5, 5, 5, 7, 6, 5, 5, 6, 5, 5, 6, 7, 7, 6, 7,
#        6, 7, 7, 5, 5, 6, 5, 5, 6, 7, 5, 6, 6, 6, 6, 6, 7, 7, 7, 7, 5, 7,
#        7, 6, 5, 7, 6, 7, 5, 7, 6, 6, 7, 6, 5, 5, 5, 7, 5, 6, 5, 7, 5, 5,
#        6, 6, 6, 5, 5, 6, 5, 6, 5, 6, 5, 6, 7, 7, 5, 7, 5, 6, 7, 7, 5, 7,
# ...

# %%
print(accuracy_score(y_test,pred)) #this is to check the accuracy of the report created. This result is 45% accurate
# Out:
# 0.4541284403669725

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[ 0  4  4  3  0]
#  [ 0 99 59 34  0]
#  [ 0 50 71 46  0]
#  [ 0  8 25 28  0]
#  [ 0  0  2  3  0]]

# %% [markdown]
# # Medical Cost Personal Insurance Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
ds= pd.read_csv("C:/Users/vaddi/Downloads/documents/medical_cost_insurance.csv")
ds
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
ds.shape
# Out:
# (1338, 7)

# %%
ds.sample()
# Out:
#     age     sex   bmi  children smoker     region   charges
# 40   24  female  26.6         0     no  northeast  3046.062

# %%
ds.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
ds.columns.tolist()
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']

# %%
ds.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
ds["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
ds.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# Changing the smoker to 1 and non-smoker to 0, considering this attribute can effect the insurance, and so can check the stats including the smoker column.

# %%
ds["smoker"]= ds["smoker"].replace("yes",1)
ds["smoker"]= ds["smoker"].replace("no",0)
ds["smoker"]
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1333    0
# 1334    0
# 1335    0
# 1336    0
# 1337    1
# Name: smoker, Length: 1338, dtype: int64

# %%
ds["sex"]= ds["sex"].replace("male",1)
ds["sex"]= ds["sex"].replace("female",0)
ds["sex"]
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1333    1
# 1334    0
# 1335    0
# 1336    0
# 1337    0
# Name: sex, Length: 1338, dtype: int64

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 73.3+ KB

# %%
#Checking number of unique values in each column
ds.nunique().to_frame("No. of unique values")
# Out:
#           No. of unique values
# age                         47
# sex                          2
# bmi                        548
# children                     6
# smoker                       2
# region                       4
# charges                   1337

# %%
sns.heatmap(ds.isnull())
# Out:
# <AxesSubplot:>

# %%
ds.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             charges
# count   1338.000000
# mean   13270.422265
# std    12110.011237
# min     1121.873900
# 25%     4740.287150
# 50%     9382.033000
# 75%    16639.912515
# max    63770.428010

# %% [markdown]
# From the above statistical summary it is understood that :
#     1. the mean is greater/less than median for age bmi childern and charges columns which means the skewness is the data is present
#     2. There is a considerable different between max value and 75%, and therefore has to check for the outliers in the data
#     3. The std values shows that the data is widely distributed.

# %% [markdown]
# # Checking for the outliers

# %%
categorical_col = []
for i in ds.dtypes.index:
    if ds.dtypes[i]== "object":
        categorical_col.append(i)
print("Categorical Columns:", categorical_col)
print("\n")

#checking for Numerical  columns
numerical_col = []
for i in ds.dtypes.index:
    if ds.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical Columns: ", numerical_col)
# Out:
# Categorical Columns: ['region']
#
#
# Numerical Columns:  ['age', 'sex', 'bmi', 'children', 'smoker', 'charges']

# %%
ds.drop('region',axis=1,inplace=True)

# %%
ds.dtypes
# Out:
# age           int64
# sex           int64
# bmi         float64
# children      int64
# smoker        int64
# charges     float64
# dtype: object

# %%
ds['age'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['sex'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['bmi'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['children'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['smoker'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['charges'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Based on the above box plot the outliers are present in charges and bmi attributes

# %% [markdown]
# checking for the skewness

# %%
sns.distplot(ds['charges'])
# Out:
# <AxesSubplot:xlabel='charges', ylabel='Density'>

# %% [markdown]
# The data is right skewed in charges

# %%
sns.distplot(ds['smoker'])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='Density'>

# %%
sns.distplot(ds['bmi'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='Density'>

# %% [markdown]
# The data is normally distributed in bmi

# %%
sns.distplot(ds['children'])
# Out:
# <AxesSubplot:xlabel='children', ylabel='Density'>

# %% [markdown]
# Data is widely spread in the childrens attribute

# %%
plt.scatter(ds['charges'],y=ds['children'])

# %% [markdown]
# verified the relation between the children and charges using the scatter plot, observed that the charges are high when there are less number of kids

# %%
plt.scatter(ds['charges'],y=ds['smoker'])

# %% [markdown]
# verified the relationship between charges and smoker and observed that the charges are high if the person is a smoker

# %%
plt.scatter(ds['charges'],y=ds['age'])

# %% [markdown]
# The difference in the age doesn't effect the charges

# %%
plt.scatter(ds['charges'],y=ds['bmi'])

# %%
plt.scatter(ds['charges'],y=ds['sex'])

# %% [markdown]
# # removing the outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(ds))
z
# Out:
#            age       sex       bmi  children    smoker   charges
# 0     1.438764  1.010519  0.453320  0.908614  1.970587  0.298584
# 1     1.509965  0.989591  0.509621  0.078767  0.507463  0.953689
# 2     0.797954  0.989591  0.383307  1.580926  0.507463  0.728675
# 3     0.441948  0.989591  1.305531  0.908614  0.507463  0.719843
# 4     0.513149  0.989591  0.292556  0.908614  0.507463  0.776802
# ...        ...       ...       ...       ...       ...       ...
# 1333  0.768473  0.989591  0.050297  1.580926  0.507463  0.220551
# 1334  1.509965  1.010519  0.206139  0.908614  0.507463  0.914002
# 1335  1.509965  1.010519  1.014878  0.908614  0.507463  0.961596
# 1336  1.296362  1.010519  0.797813  0.908614  0.507463  0.930362
# 1337  1.551686  1.010519  0.261388  0.908614  1.970587  1.311053
#
# [1338 rows x 6 columns]

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  32,   34,   71,  116,  166,  413,  425,  438,  543,  568,  577,
#         640,  819,  847,  877,  932,  937,  969,  984, 1047, 1085, 1116,
#        1130, 1146, 1230, 1245, 1272, 1300, 1317], dtype=int64), array([3, 5, 3, 2, 3, 3, 3, 3, 5, 3, 5, 3, 5, 2, 3, 3, 3, 3, 3, 2, 3, 3,
#        3, 5, 5, 3, 3, 5, 2], dtype=int64))

# %%
ds_new=ds[(z<3).all(axis=1)]

# %%
ds_new
# Out:
#       age  sex     bmi  children  smoker      charges
# 0      19    0  27.900         0       1  16884.92400
# 1      18    1  33.770         1       0   1725.55230
# 2      28    1  33.000         3       0   4449.46200
# 3      33    1  22.705         0       0  21984.47061
# 4      32    1  28.880         0       0   3866.85520
# ...   ...  ...     ...       ...     ...          ...
# 1333   50    1  30.970         3       0  10600.54830
# 1334   18    0  31.920         0       0   2205.98080
# 1335   18    0  36.850         0       0   1629.83350
# 1336   21    0  25.800         0       0   2007.94500
# 1337   61    0  29.070         0       1  29141.36030
#
# [1309 rows x 6 columns]

# %% [markdown]
#  i am not sure what kind of ML method is used to predict the insurance cost
